# %% [markdown]
# #**Assignment-04**

# %% [markdown]
# I've selected the "Iris" dataset from the UCI Machine Learning Repository, which is also available on Kaggle. This classic dataset contains measurements of iris flowers from three different species: Setosa, Versicolor, and Virginica.
#
# #**First 5 Rows of the Dataset:**

# %%
import pandas as pd

# Load the dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
column_names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]
data = pd.read_csv(url, header=None, names=column_names)

# Display the first 5 rows
print(data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Dataset Shape:

# %%
print(data.shape)
# Out:
# (150, 5)

# %% [markdown]
# 100 Real-World Questions Solvable with Numpy, Pandas, Matplotlib, and Seaborn:
#
# 1.What is the average sepal length for each species?
#
# 2.What is the average sepal width for each species?
#
# 3.What is the average petal length for each species?
#
# 4.What is the average petal width for each species?
#
# 5.What is the overall average sepal length?
#
# 6.What is the overall average sepal width?
#
# 7.What is the overall average petal length?
#
# 8.What is the overall average petal width?
#
# 9.What is the median sepal length for each species?
#
# 10.What is the median sepal width for each species?
#
# 11.What is the median petal length for each species?
#
# 12.What is the median petal width for each species?
#
# 13.What is the overall median sepal length?
#
# 14.What is the overall median sepal width?
#
# 15.What is the overall median petal length?
#
# 16.What is the overall median petal width?
#
# 17.What is the standard deviation of sepal length for each species?
#
# 18.What is the standard deviation of sepal width for each species?
#
# 19.What is the standard deviation of petal length for each species?
#
# 20.What is the standard deviation of petal width for each species?
#
# 21.What is the overall standard deviation of sepal length?
#
# 22.What is the overall standard deviation of sepal width?
#
# 23.What is the overall standard deviation of petal length?
#
# 24.What is the overall standard deviation of petal width?
#
# 25.What is the minimum sepal length for each species?
#
# 26.What is the minimum sepal width for each species?
#
# 27.What is the minimum petal length for each species?
#
# 28.What is the minimum petal width for each species?
#
# 29.What is the maximum sepal length for each species?
#
# 30.What is the maximum sepal width for each species?
#
# 31.What is the maximum petal length for each species?
#
# 32.What is the maximum petal width for each species?
#
# 33.What is the overall minimum sepal length?
#
# 34.What is the overall minimum sepal width?
#
# 35.What is the overall minimum petal length?
#
# 36.What is the overall minimum petal width?
#
# 37.What is the overall maximum sepal length?
#
# 38.What is the overall maximum sepal width?
#
# 39.What is the overall maximum petal length?
#
# 40.What is the overall maximum petal width?
#
# 41.What is the range of sepal length for each species?
#
# 42.What is the range of sepal width for each species?
#
# 43.What is the range of petal length for each species?
#
# 44.What is the range of petal width for each species?
#
# 45.What is the overall range of sepal length?
#
# 46.What is the overall range of sepal width?
#
# 47.What is the overall range of petal length?
#
# 48.What is the overall range of petal width?
#
# 49.What is the interquartile range (IQR) of sepal length for each species?
#
# 50.What is the interquartile range (IQR) of sepal width for each species?
#
# #**Descriptive Statistics & Data Exploration**
#
# 51.What is the correlation between sepal length and sepal width?
#
# 52.What is the correlation between petal length and petal width?
#
# 53.What is the correlation between sepal length and petal length?
#
# 54.What is the correlation between sepal width and petal width?
#
# 55.What is the species-wise correlation between different features?
#
# 56.How many samples belong to each species?
#
# 57.Are there any duplicate rows in the dataset?
#
# 58.Are there any missing values in the dataset?
#
# 59.What are the summary statistics for each feature in the dataset?
#
# 60.What is the coefficient of variation for each species?
#
# #**Data Visualization - Univariate Analysis**
#
# 61.Plot the distribution of sepal length for each species.
#
# 62.Plot the distribution of sepal width for each species.
#
# 63.Plot the distribution of petal length for each species.
#
# 64.Plot the distribution of petal width for each species.
#
# 65.Create a histogram for sepal length.
#
# 66.Create a histogram for sepal width.
#
# 67.Create a histogram for petal length.
#
# 68.Create a histogram for petal width.
#
# 69.Create a boxplot for sepal length across species.
#
# 70.Create a boxplot for sepal width across species.
#
# 71.Create a boxplot for petal length across species.
#
# 72.Create a boxplot for petal width across species.
#
# 73.Create a violin plot for sepal length.
#
# 74.Create a violin plot for petal length.
#
# 75.Create a KDE (Kernel Density Estimation) plot for petal width.
#
# #**Data Visualization - Bivariate Analysis**
#
# 76.Create a scatter plot of sepal length vs. sepal width for all species.
#
# 77.Create a scatter plot of petal length vs. petal width for all species.
#
# 78.Create a scatter plot of sepal length vs. petal length for all species.
#
# 79.Create a scatter plot of sepal width vs. petal width for all species.
#
# 80.Create pair plots to visualize relationships between all features.
#
# 81.Create a heatmap of the correlation matrix between numerical features.
#
# 82.Create a count plot to show the number of samples per species.
#
# 83.Create a swarm plot to visualize petal length across species.
#
# 84.Create a hexbin plot for sepal width and petal width.
#
# 85.Create a stacked bar chart for species distribution.
#
# #**Data Transformation & Feature Engineering**
#
# 86.Normalize the sepal length feature using Min-Max scaling.
#
# 87.Standardize the petal width feature using Z-score normalization.
#
# 88.Create a new feature that is the ratio of petal length to petal width.
#
# 89.Create a new feature that is the product of sepal length and sepal width.
#
# 90.Discretize the sepal length into categories (small, medium, large).
#
# 91.Find outliers in petal length using the IQR method.
#
# 92.Find outliers in sepal width using the Z-score method.
#
# 93.Perform Principal Component Analysis (PCA) on the dataset.
#
# 94.Reduce the dataset dimensions using PCA and visualize it in 2D.
#
# 95.Convert categorical species names into numerical labels.
#
# 96.Encode species names using one-hot encoding.
#
# 97.Find the top two features that contribute the most to species classification.
#
# 98.Identify the most important feature in differentiating species.
#
# 99.Build a simple logistic regression model to classify species.
#
# 100.Evaluate the logistic regression model’s accuracy using cross-validation.

# %% [markdown]
# 1.What is the average sepal length for each species?

# %%
import pandas as pd
import seaborn as sns

# Load the Iris dataset
iris = sns.load_dataset("iris")

# Compute the average sepal length for each species
avg_sepal_length = iris.groupby("species")["sepal_length"].mean()

# Display result
print(avg_sepal_length)
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %% [markdown]
# 2. What is the average sepal width for each species?

# %%
avg_sepal_width = iris.groupby("species")["sepal_width"].mean()
print(avg_sepal_width)
# Out:
# species
# setosa        3.428
# versicolor    2.770
# virginica     2.974
# Name: sepal_width, dtype: float64

# %% [markdown]
# 3. What is the average petal length for each species?

# %%
avg_petal_length = iris.groupby("species")["petal_length"].mean()
print(avg_petal_length)
# Out:
# species
# setosa        1.462
# versicolor    4.260
# virginica     5.552
# Name: petal_length, dtype: float64

# %% [markdown]
# 4. What is the average petal width for each species?

# %%
avg_petal_width = iris.groupby("species")["petal_width"].mean()
print(avg_petal_width)
# Out:
# species
# setosa        0.246
# versicolor    1.326
# virginica     2.026
# Name: petal_width, dtype: float64

# %% [markdown]
# 5. What is the overall average sepal length?

# %%
overall_avg_sepal_length = iris["sepal_length"].mean()
print(overall_avg_sepal_length)
# Out:
# 5.843333333333334

# %% [markdown]
# 6. What is the overall average sepal width?

# %%
overall_avg_sepal_width = iris["sepal_width"].mean()
print(overall_avg_sepal_width)
# Out:
# 3.0573333333333337

# %% [markdown]
# 7. What is the overall average petal length?

# %%
overall_avg_petal_length = iris["petal_length"].mean()
print(overall_avg_petal_length)
# Out:
# 3.7580000000000005

# %% [markdown]
# 8. What is the overall average petal width?

# %%
overall_avg_petal_width = iris["petal_width"].mean()
print(overall_avg_petal_width)
# Out:
# 1.1993333333333336

# %% [markdown]
# 9. What is the median sepal length for each species?

# %%
median_sepal_length = iris.groupby("species")["sepal_length"].median()
print(median_sepal_length)
# Out:
# species
# setosa        5.0
# versicolor    5.9
# virginica     6.5
# Name: sepal_length, dtype: float64

# %% [markdown]
# 10. What is the median sepal width for each species?

# %%
median_sepal_width = iris.groupby("species")["sepal_width"].median()
print(median_sepal_width)
# Out:
# species
# setosa        3.4
# versicolor    2.8
# virginica     3.0
# Name: sepal_width, dtype: float64

# %% [markdown]
# 11. What is the median petal length for each species?
# python
# Copy
# Edit

# %%
median_petal_length = iris.groupby("species")["petal_length"].median()
print(median_petal_length)
# Out:
# species
# setosa        1.50
# versicolor    4.35
# virginica     5.55
# Name: petal_length, dtype: float64

# %% [markdown]
# 12. What is the median petal width for each species?

# %%
median_petal_width = iris.groupby("species")["petal_width"].median()
print(median_petal_width)
# Out:
# species
# setosa        0.2
# versicolor    1.3
# virginica     2.0
# Name: petal_width, dtype: float64

# %% [markdown]
# 13. What is the overall median sepal length?

# %%
overall_median_sepal_length = iris["sepal_length"].median()
print(overall_median_sepal_length)
# Out:
# 5.8

# %% [markdown]
# 14. What is the overall median sepal width?

# %%
overall_median_sepal_width = iris["sepal_width"].median()
print(overall_median_sepal_width)
# Out:
# 3.0

# %% [markdown]
# 15. What is the overall median petal length?

# %%
overall_median_petal_length = iris["petal_length"].median()
print(overall_median_petal_length)
# Out:
# 4.35

# %% [markdown]
# 16. What is the overall median petal width?

# %%
overall_median_petal_width = iris["petal_width"].median()
print(overall_median_petal_width)
# Out:
# 1.3

# %% [markdown]
# 17. What is the standard deviation of sepal length for each species?

# %%
std_sepal_length = iris.groupby("species")["sepal_length"].std()
print(std_sepal_length)
# Out:
# species
# setosa        0.352490
# versicolor    0.516171
# virginica     0.635880
# Name: sepal_length, dtype: float64

# %% [markdown]
# 18. What is the standard deviation of sepal width for each species?

# %%
std_sepal_width = iris.groupby("species")["sepal_width"].std()
print(std_sepal_width)
# Out:
# species
# setosa        0.379064
# versicolor    0.313798
# virginica     0.322497
# Name: sepal_width, dtype: float64

# %% [markdown]
# 19. What is the standard deviation of petal length for each species?

# %%
std_petal_length = iris.groupby("species")["petal_length"].std()
print(std_petal_length)
# Out:
# species
# setosa        0.173664
# versicolor    0.469911
# virginica     0.551895
# Name: petal_length, dtype: float64

# %% [markdown]
# 20. What is the standard deviation of petal width for each species?

# %%
std_petal_width = iris.groupby("species")["petal_width"].std()
print(std_petal_width)
# Out:
# species
# setosa        0.105386
# versicolor    0.197753
# virginica     0.274650
# Name: petal_width, dtype: float64

# %% [markdown]
# 21. What is the overall standard deviation of sepal length?

# %%
overall_std_sepal_length = iris["sepal_length"].std()
print(overall_std_sepal_length)
# Out:
# 0.8280661279778629

# %% [markdown]
# 22. What is the overall standard deviation of sepal width?

# %%
overall_std_sepal_width = iris["sepal_width"].std()
print(overall_std_sepal_width)
# Out:
# 0.435866284936698

# %% [markdown]
# 23. What is the overall standard deviation of petal length?

# %%
overall_std_petal_length = iris["petal_length"].std()
print(overall_std_petal_length)
# Out:
# 1.7652982332594667

# %% [markdown]
# 24. What is the overall standard deviation of petal width?

# %%
overall_std_petal_width = iris["petal_width"].std()
print(overall_std_petal_width)
# Out:
# 0.7622376689603465

# %% [markdown]
# 25. What is the minimum sepal length for each species?

# %%
min_sepal_length = iris.groupby("species")["sepal_length"].min()
print(min_sepal_length)
# Out:
# species
# setosa        4.3
# versicolor    4.9
# virginica     4.9
# Name: sepal_length, dtype: float64

# %% [markdown]
# 26. What is the minimum sepal width for each species?

# %%
min_sepal_width = iris.groupby("species")["sepal_width"].min()
print(min_sepal_width)
# Out:
# species
# setosa        2.3
# versicolor    2.0
# virginica     2.2
# Name: sepal_width, dtype: float64

# %% [markdown]
# 27. What is the minimum petal length for each species?

# %%
min_petal_length = iris.groupby("species")["petal_length"].min()
print(min_petal_length)
# Out:
# species
# setosa        1.0
# versicolor    3.0
# virginica     4.5
# Name: petal_length, dtype: float64

# %% [markdown]
# 28. What is the minimum petal width for each species?

# %%
min_petal_width = iris.groupby("species")["petal_width"].min()
print(min_petal_width)
# Out:
# species
# setosa        0.1
# versicolor    1.0
# virginica     1.4
# Name: petal_width, dtype: float64

# %% [markdown]
# 29. What is the maximum sepal length for each species?

# %%
max_sepal_length = iris.groupby("species")["sepal_length"].max()
print(max_sepal_length)
# Out:
# species
# setosa        5.8
# versicolor    7.0
# virginica     7.9
# Name: sepal_length, dtype: float64

# %% [markdown]
# 30. What is the maximum sepal width for each species?

# %%
max_sepal_width = iris.groupby("species")["sepal_width"].max()
print(max_sepal_width)
# Out:
# species
# setosa        4.4
# versicolor    3.4
# virginica     3.8
# Name: sepal_width, dtype: float64

# %% [markdown]
# 31. What is the maximum petal length for each species?

# %%
max_petal_length = iris.groupby("species")["petal_length"].max()
print(max_petal_length)
# Out:
# species
# setosa        1.9
# versicolor    5.1
# virginica     6.9
# Name: petal_length, dtype: float64

# %% [markdown]
# 32. What is the maximum petal width for each species?

# %%
max_petal_width = iris.groupby("species")["petal_width"].max()
print(max_petal_width)
# Out:
# species
# setosa        0.6
# versicolor    1.8
# virginica     2.5
# Name: petal_width, dtype: float64

# %% [markdown]
# 33. What is the overall minimum sepal length?

# %%
overall_min_sepal_length = iris["sepal_length"].min()
print(overall_min_sepal_length)
# Out:
# 4.3

# %% [markdown]
# 34. What is the overall minimum sepal width?

# %%
overall_min_sepal_width = iris["sepal_width"].min()
print(overall_min_sepal_width)
# Out:
# 2.0

# %% [markdown]
# 35. What is the overall minimum petal length?

# %%
overall_min_petal_length = iris["petal_length"].min()
print(overall_min_petal_length)
# Out:
# 1.0

# %% [markdown]
# 36. What is the overall minimum petal width?

# %%
overall_min_petal_width = iris["petal_width"].min()
print(overall_min_petal_width)
# Out:
# 0.1

# %% [markdown]
# 37. What is the overall maximum sepal length?

# %%
overall_max_sepal_length = iris["sepal_length"].max()
print(overall_max_sepal_length)
# Out:
# 7.9

# %% [markdown]
# 38. What is the overall maximum sepal width?

# %%
overall_max_sepal_width = iris["sepal_width"].max()
print(overall_max_sepal_width)
# Out:
# 4.4

# %% [markdown]
# 39. What is the overall maximum petal length?

# %%
overall_max_petal_length = iris["petal_length"].max()
print(overall_max_petal_length)
# Out:
# 6.9

# %% [markdown]
# 40. What is the overall maximum petal width?

# %%
overall_max_petal_width = iris["petal_width"].max()
print(overall_max_petal_width)
# Out:
# 2.5

# %% [markdown]
# 41. What is the range of sepal length for each species?

# %%
range_sepal_length = iris.groupby("species")["sepal_length"].apply(lambda x: x.max() - x.min())
print(range_sepal_length)
# Out:
# species
# setosa        1.5
# versicolor    2.1
# virginica     3.0
# Name: sepal_length, dtype: float64

# %% [markdown]
# 42. What is the range of sepal width for each species?

# %%
range_sepal_width = iris.groupby("species")["sepal_width"].apply(lambda x: x.max() - x.min())
print(range_sepal_width)
# Out:
# species
# setosa        2.1
# versicolor    1.4
# virginica     1.6
# Name: sepal_width, dtype: float64

# %% [markdown]
# 43. What is the range of petal length for each species?

# %%
range_petal_length = iris.groupby("species")["petal_length"].apply(lambda x: x.max() - x.min())
print(range_petal_length)
# Out:
# species
# setosa        0.9
# versicolor    2.1
# virginica     2.4
# Name: petal_length, dtype: float64

# %% [markdown]
# 44. What is the range of petal width for each species?

# %%
range_petal_width = iris.groupby("species")["petal_width"].apply(lambda x: x.max() - x.min())
print(range_petal_width)
# Out:
# species
# setosa        0.5
# versicolor    0.8
# virginica     1.1
# Name: petal_width, dtype: float64

# %% [markdown]
# 45. What is the overall range of sepal length?

# %%
overall_range_sepal_length = iris["sepal_length"].max() - iris["sepal_length"].min()
print(overall_range_sepal_length)
# Out:
# 3.6000000000000005

# %% [markdown]
# 46. What is the overall range of sepal width?

# %%
overall_range_sepal_width = iris["sepal_width"].max() - iris["sepal_width"].min()
print(overall_range_sepal_width)
# Out:
# 2.4000000000000004

# %% [markdown]
# 47. What is the overall range of petal length?

# %%
overall_range_petal_length = iris["petal_length"].max() - iris["petal_length"].min()
print(overall_range_petal_length)
# Out:
# 5.9

# %% [markdown]
# 48. What is the overall range of petal width?

# %%
overall_range_petal_width = iris["petal_width"].max() - iris["petal_width"].min()
print(overall_range_petal_width)
# Out:
# 2.4

# %% [markdown]
# 49. What is the interquartile range (IQR) of sepal length for each species?

# %%
iqr_sepal_length = iris.groupby("species")["sepal_length"].apply(lambda x: x.quantile(0.75) - x.quantile(0.25))
print(iqr_sepal_length)
# Out:
# species
# setosa        0.400
# versicolor    0.700
# virginica     0.675
# Name: sepal_length, dtype: float64

# %% [markdown]
# 50. What is the interquartile range (IQR) of sepal width for each species?

# %%
iqr_sepal_width = iris.groupby("species")["sepal_width"].apply(lambda x: x.quantile(0.75) - x.quantile(0.25))
print(iqr_sepal_width)
# Out:
# species
# setosa        0.475
# versicolor    0.475
# virginica     0.375
# Name: sepal_width, dtype: float64

# %% [markdown]
# #**Descriptive Statistics & Data Exploration**
# 51. What is the correlation between sepal length and sepal width?

# %%
correlation_sepal = iris["sepal_length"].corr(iris["sepal_width"])
print(correlation_sepal)
# Out:
# -0.11756978413300208

# %% [markdown]
# 52. What is the correlation between petal length and petal width?

# %%
correlation_petal = iris["petal_length"].corr(iris["petal_width"])
print(correlation_petal)
# Out:
# 0.9628654314027961

# %% [markdown]
# 53. What is the correlation between sepal length and petal length?

# %%
correlation_sepal_petal = iris["sepal_length"].corr(iris["petal_length"])
print(correlation_sepal_petal)
# Out:
# 0.8717537758865831

# %% [markdown]
# 54. What is the correlation between sepal width and petal width?

# %%
correlation_sepal_petal_width = iris["sepal_width"].corr(iris["petal_width"])
print(correlation_sepal_petal_width)
# Out:
# -0.36612593253643927

# %% [markdown]
# 55. What is the species-wise correlation between different features?

# %%
species_correlation = iris.groupby("species").corr()
print(species_correlation)
# Out:
#                          sepal_length  sepal_width  petal_length  petal_width
# species
# setosa     sepal_length      1.000000     0.742547      0.267176     0.278098
#            sepal_width       0.742547     1.000000      0.177700     0.232752
#            petal_length      0.267176     0.177700      1.000000     0.331630
#            petal_width       0.278098     0.232752      0.331630     1.000000
# versicolor sepal_length      1.000000     0.525911      0.754049     0.546461
#            sepal_width       0.525911     1.000000      0.560522     0.663999
#            petal_length      0.754049     0.560522      1.000000     0.786668
#            petal_width       0.546461     0.663999      0.786668     1.000000
# virginica  sepal_length      1.000000     0.457228      0.864225     0.281108
#            sepal_width       0.457228     1.000000      0.401045     0.537728
#            petal_length      0.864225     0.401045      1.000000     0.322108
#            petal_width       0.281108     0.537728      0.322108     1.000000

# %% [markdown]
# 56. How many samples belong to each species?

# %%
species_count = iris["species"].value_counts()
print(species_count)
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# 57. Are there any duplicate rows in the dataset?

# %%
duplicates = iris.duplicated().sum()
print(duplicates)
# Out:
# 1

# %% [markdown]
# 58. Are there any missing values in the dataset?

# %%
missing_values = iris.isnull().sum()
print(missing_values)
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# 59. What are the summary statistics for each feature in the dataset?

# %%
summary_statistics = iris.describe()
print(summary_statistics)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# 60. What is the coefficient of variation for each species?

# %%
cv_species = iris.groupby("species").std() / iris.groupby("species").mean()
print(cv_species)
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          0.070413     0.110579      0.118785     0.428397
# versicolor      0.086956     0.113285      0.110308     0.149135
# virginica       0.096521     0.108439      0.099405     0.135563

# %% [markdown]
# 61. Plot the distribution of sepal length for each species

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=iris, x="sepal_length", hue="species", kde=True, bins=20)
plt.title("Distribution of Sepal Length for Each Species")
plt.show()

# %% [markdown]
# 62. Plot the distribution of sepal width for each species

# %%
sns.histplot(data=iris, x="sepal_width", hue="species", kde=True, bins=20)
plt.title("Distribution of Sepal Width for Each Species")
plt.show()

# %% [markdown]
# 63. Plot the distribution of petal length for each species

# %%
sns.histplot(data=iris, x="petal_length", hue="species", kde=True, bins=20)
plt.title("Distribution of Petal Length for Each Species")
plt.show()

# %% [markdown]
# 64. Plot the distribution of petal width for each species

# %%
sns.histplot(data=iris, x="petal_width", hue="species", kde=True, bins=20)
plt.title("Distribution of Petal Width for Each Species")
plt.show()

# %% [markdown]
# 65. Create a histogram for sepal length

# %%
plt.hist(iris["sepal_length"], bins=20, color="blue", alpha=0.7)
plt.title("Histogram of Sepal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 66. Create a histogram for sepal width

# %%
plt.hist(iris["sepal_width"], bins=20, color="green", alpha=0.7)
plt.title("Histogram of Sepal Width")
plt.xlabel("Sepal Width")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 67. Create a histogram for petal length

# %%
plt.hist(iris["petal_length"], bins=20, color="red", alpha=0.7)
plt.title("Histogram of Petal Length")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 68. Create a histogram for petal width

# %%
plt.hist(iris["petal_width"], bins=20, color="purple", alpha=0.7)
plt.title("Histogram of Petal Width")
plt.xlabel("Petal Width")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 69. Create a boxplot for sepal length across species

# %%
sns.boxplot(x="species", y="sepal_length", data=iris)
plt.title("Boxplot of Sepal Length Across Species")
plt.show()

# %% [markdown]
# 70. Create a boxplot for sepal width across species

# %%
sns.boxplot(x="species", y="sepal_width", data=iris)
plt.title("Boxplot of Sepal Width Across Species")
plt.show()

# %% [markdown]
# 71. Create a boxplot for petal length across species

# %%
sns.boxplot(x="species", y="petal_length", data=iris)
plt.title("Boxplot of Petal Length Across Species")
plt.show()

# %% [markdown]
# 72. Create a boxplot for petal width across species

# %%
sns.boxplot(x="species", y="petal_width", data=iris)
plt.title("Boxplot of Petal Width Across Species")
plt.show()

# %% [markdown]
# 73. Create a violin plot for sepal length

# %%
sns.violinplot(x="species", y="sepal_length", data=iris)
plt.title("Violin Plot of Sepal Length")
plt.show()

# %% [markdown]
# 74. Create a violin plot for petal length

# %%
sns.violinplot(x="species", y="petal_length", data=iris)
plt.title("Violin Plot of Petal Length")
plt.show()

# %% [markdown]
# 75. Create a KDE (Kernel Density Estimation) plot for petal width

# %%
sns.kdeplot(data=iris, x="petal_width", hue="species", fill=True)
plt.title("KDE Plot of Petal Width")
plt.show()

# %% [markdown]
# #**Data Visualization - Bivariate Analysis**
# 76. Scatter plot of sepal length vs. sepal width for all species

# %%
sns.scatterplot(x="sepal_length", y="sepal_width", hue="species", data=iris)
plt.title("Scatter Plot of Sepal Length vs. Sepal Width")
plt.show()

# %% [markdown]
# 77. Scatter plot of petal length vs. petal width for all species

# %%
sns.scatterplot(x="petal_length", y="petal_width", hue="species", data=iris)
plt.title("Scatter Plot of Petal Length vs. Petal Width")
plt.show()

# %% [markdown]
# 78. Scatter plot of sepal length vs. petal length for all species

# %%
sns.scatterplot(x="sepal_length", y="petal_length", hue="species", data=iris)
plt.title("Scatter Plot of Sepal Length vs. Petal Length")
plt.show()

# %% [markdown]
# 79. Scatter plot of sepal width vs. petal width for all species

# %%
sns.scatterplot(x="sepal_width", y="petal_width", hue="species", data=iris)
plt.title("Scatter Plot of Sepal Width vs. Petal Width")
plt.show()

# %% [markdown]
# 80. Pair plots to visualize relationships between all features

# %%
sns.pairplot(iris, hue="species")
plt.show()

# %% [markdown]
# 81. Heatmap of the correlation matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
iris = sns.load_dataset("iris")

# Compute the correlation matrix
correlation_matrix = iris.drop(columns=["species"]).corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# 82. Count plot to show number of samples per species

# %%
sns.countplot(x="species", data=iris)
plt.title("Count of Each Species in the Dataset")
plt.show()

# %% [markdown]
# 83. Swarm plot to visualize petal length across species

# %%
sns.swarmplot(x="species", y="petal_length", data=iris)
plt.title("Swarm Plot of Petal Length Across Species")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 84. Hexbin plot for sepal width and petal width

# %%
plt.hexbin(iris["sepal_width"], iris["petal_width"], gridsize=30, cmap="Blues")
plt.colorbar(label="Count")
plt.xlabel("Sepal Width")
plt.ylabel("Petal Width")
plt.title("Hexbin Plot of Sepal Width vs. Petal Width")
plt.show()

# %% [markdown]
# 85. Stacked bar chart for species distribution

# %%
species_counts = iris["species"].value_counts()
species_counts.plot(kind="bar", stacked=True, color=["blue", "red", "green"])
plt.title("Stacked Bar Chart of Species Distribution")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# 86. Normalize the sepal length feature using Min-Max scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
iris["sepal_length_normalized"] = scaler.fit_transform(iris[["sepal_length"]])
print(iris[["sepal_length", "sepal_length_normalized"]].head())
# Out:
#    sepal_length  sepal_length_normalized
# 0           5.1                 0.222222
# 1           4.9                 0.166667
# 2           4.7                 0.111111
# 3           4.6                 0.083333
# 4           5.0                 0.194444

# %% [markdown]
# 87. Standardize the petal width feature using Z-score normalization

# %%
from scipy.stats import zscore

iris["petal_width_standardized"] = zscore(iris["petal_width"])
print(iris[["petal_width", "petal_width_standardized"]].head())
# Out:
#    petal_width  petal_width_standardized
# 0          0.2                 -1.315444
# 1          0.2                 -1.315444
# 2          0.2                 -1.315444
# 3          0.2                 -1.315444
# 4          0.2                 -1.315444

# %% [markdown]
# 88. Create a new feature that is the ratio of petal length to petal width

# %%
iris["petal_length_to_width_ratio"] = iris["petal_length"] / iris["petal_width"]
print(iris[["petal_length", "petal_width", "petal_length_to_width_ratio"]].head())
# Out:
#    petal_length  petal_width  petal_length_to_width_ratio
# 0           1.4          0.2                          7.0
# 1           1.4          0.2                          7.0
# 2           1.3          0.2                          6.5
# 3           1.5          0.2                          7.5
# 4           1.4          0.2                          7.0

# %% [markdown]
# 89. Create a new feature that is the product of sepal length and sepal width

# %%
iris["sepal_area"] = iris["sepal_length"] * iris["sepal_width"]
print(iris[["sepal_length", "sepal_width", "sepal_area"]].head())
# Out:
#    sepal_length  sepal_width  sepal_area
# 0           5.1          3.5       17.85
# 1           4.9          3.0       14.70
# 2           4.7          3.2       15.04
# 3           4.6          3.1       14.26
# 4           5.0          3.6       18.00

# %% [markdown]
# 90. Discretize the sepal length into categories (small, medium, large)

# %%
bins = [0, 5.0, 6.0, 8.0]
labels = ["Small", "Medium", "Large"]
iris["sepal_length_category"] = pd.cut(iris["sepal_length"], bins=bins, labels=labels)
print(iris[["sepal_length", "sepal_length_category"]].head())
# Out:
#    sepal_length sepal_length_category
# 0           5.1                Medium
# 1           4.9                 Small
# 2           4.7                 Small
# 3           4.6                 Small
# 4           5.0                 Small

# %% [markdown]
# 91. Find outliers in petal length using the IQR method

# %%
Q1 = iris["petal_length"].quantile(0.25)
Q3 = iris["petal_length"].quantile(0.75)
IQR = Q3 - Q1

outliers = iris[(iris["petal_length"] < (Q1 - 1.5 * IQR)) | (iris["petal_length"] > (Q3 + 1.5 * IQR))]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species, sepal_length_normalized, petal_width_standardized, petal_length_to_width_ratio, sepal_area, sepal_length_category]
# Index: []

# %% [markdown]
# 92. Find outliers in sepal width using the Z-score method

# %%
from scipy.stats import zscore

iris["sepal_width_zscore"] = zscore(iris["sepal_width"])
outliers = iris[abs(iris["sepal_width_zscore"]) > 3]
print(outliers)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species  \
# 15           5.7          4.4           1.5          0.4  setosa
#
#     sepal_length_normalized  petal_width_standardized  \
# 15                 0.388889                  -1.05218
#
#     petal_length_to_width_ratio  sepal_area sepal_length_category  \
# 15                         3.75       25.08                Medium
#
#     sepal_width_zscore
# 15            3.090775

# %% [markdown]
# 93. Perform Principal Component Analysis (PCA) on the dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Load the dataset
iris = sns.load_dataset("iris")

# Drop the categorical column
X = iris.drop(columns=["species"])

# Standardize the data (PCA works best with standardized data)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Perform PCA (keeping all components)
pca = PCA(n_components=X.shape[1])  # Keep all components
principal_components = pca.fit_transform(X_scaled)

# Explained variance ratio
explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance)

# Cumulative explained variance plot
plt.figure(figsize=(8, 5))
plt.plot(range(1, X.shape[1] + 1), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Explained Variance by Principal Components")
plt.grid(True)
plt.show()
# Out:
# Explained Variance Ratio: [0.72962445 0.22850762 0.03668922 0.00517871]

# %% [markdown]
# 94. Reduce the dataset dimensions using PCA and visualize it in 2D

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Load the dataset
iris = sns.load_dataset("iris")

# Drop the categorical column
X = iris.drop(columns=["species"])

# Standardize the data (PCA works best with standardized data)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Perform PCA (keeping all components)
pca = PCA(n_components=X.shape[1])  # Keep all components
principal_components = pca.fit_transform(X_scaled)

# Explained variance ratio
explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance)

# Cumulative explained variance plot
plt.figure(figsize=(8, 5))
plt.plot(range(1, X.shape[1] + 1), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Explained Variance by Principal Components")
plt.grid(True)
plt.show()
# Out:
# Explained Variance Ratio: [0.72962445 0.22850762 0.03668922 0.00517871]

# %% [markdown]
# 95. Convert categorical species names into numerical labels

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
iris["species_encoded"] = encoder.fit_transform(iris["species"])
print(iris[["species", "species_encoded"]].head())
# Out:
#   species  species_encoded
# 0  setosa                0
# 1  setosa                0
# 2  setosa                0
# 3  setosa                0
# 4  setosa                0

# %% [markdown]
# 96. Encode species names using one-hot encoding

# %%
iris_encoded = pd.get_dummies(iris, columns=["species"])
print(iris_encoded.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  \
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
#
#    sepal_length_normalized  petal_width_standardized  \
# 0                 0.222222                 -1.315444
# 1                 0.166667                 -1.315444
# 2                 0.111111                 -1.315444
# 3                 0.083333                 -1.315444
# 4                 0.194444                 -1.315444
#
#    petal_length_to_width_ratio  sepal_area sepal_length_category  \
# 0                          7.0       17.85                Medium
# 1                          7.0       14.70                 Small
# 2                          6.5       15.04                 Small
# 3                          7.5       14.26                 Small
# 4                          7.0       18.00                 Small
#
#    sepal_width_zscore  species_encoded  species_setosa  species_versicolor  \
# 0            1.019004                0            True               False
# 1           -0.131979                0            True               False
# 2            0.328414                0            True               False
# 3            0.098217                0            True               False
# 4            1.249201                0            True               False
#
#    species_virginica
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False

# %% [markdown]
# 97. Find the top two features that contribute the most to species classification

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Load the dataset
iris = sns.load_dataset("iris")

# Separate features and target
X = iris.drop(columns=["species"])  # Only numerical features

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Perform PCA
pca = PCA(n_components=4)  # We have 4 numerical features
pca.fit(X_scaled)

# Get the PCA component loadings
loadings = np.abs(pca.components_[0])  # First principal component

# Create a DataFrame for better visualization
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': loadings})
feature_importance = feature_importance.sort_values(by="Importance", ascending=False)

# Display the top 2 most important features
print("Top 2 features contributing most to species classification:")
print(feature_importance.head(2))
# Out:
# Top 2 features contributing most to species classification:
#         Feature  Importance
# 2  petal_length    0.580413
# 3   petal_width    0.564857

# %% [markdown]
# 98. Identify the most important feature in differentiating species

# %%
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder

# Load the dataset
iris = sns.load_dataset("iris")

# Separate features and target variable
X = iris.drop(columns=["species"])  # Numerical features
y = iris["species"]

# Encode the target variable (convert categorical to numerical)
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

# Train a Decision Tree Classifier
clf = DecisionTreeClassifier()
clf.fit(X, y_encoded)

# Get feature importances
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': clf.feature_importances_})
feature_importance = feature_importance.sort_values(by="Importance", ascending=False)

# Display the most important feature
print("Most important feature for species classification:")
print(feature_importance.head(1))
# Out:
# Most important feature for species classification:
#         Feature  Importance
# 2  petal_length    0.564056

# %% [markdown]
# 99. Build a simple logistic regression model to classify species

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load the dataset
iris = sns.load_dataset("iris")

# Separate features and target
X = iris.drop(columns=["species"])
y = iris["species"]

# Encode species names into numerical labels
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

# Split the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train a Logistic Regression model
model = LogisticRegression()
model.fit(X_train_scaled, y_train)

# Make predictions
y_pred = model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Logistic Regression Model Accuracy: {accuracy:.2f}")
# Out:
# Logistic Regression Model Accuracy: 1.00

# %% [markdown]
# 100. Evaluate the logistic regression model’s accuracy using cross-validation

# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# Load the dataset
iris = sns.load_dataset("iris")

# Separate features and target variable
X = iris.drop(columns=["species"])
y = iris["species"]

# Encode species names into numerical labels
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train a Logistic Regression model with cross-validation
model = LogisticRegression()
cv_scores = cross_val_score(model, X_scaled, y_encoded, cv=5)  # 5-fold cross-validation

# Print the results
print(f"Cross-Validation Accuracy Scores: {cv_scores}")
print(f"Mean Accuracy: {cv_scores.mean():.2f}")
# Out:
# Cross-Validation Accuracy Scores: [0.96666667 1.         0.93333333 0.9        1.        ]
# Mean Accuracy: 0.96
